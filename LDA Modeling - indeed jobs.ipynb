# %%
# import libraries

from bs4 import BeautifulSoup # For HTML parsing
import urllib # Website connections
import requests
import re # Regular expressions
from time import sleep # To prevent overwhelming the server between connections
from collections import Counter # Keep track of our term counts
from nltk.corpus import stopwords # Filter out stopwords, such as 'the', 'or', 'and'
import pandas as pd # For converting results to a dataframe and bar chart plots
import matplotlib
import nltk
import random

# %%
def headers():
    i = random.randint(3,5)
    j=random.randint(40,53)
    x=random.randint(2,13)
    url_base = 'https://www.indeed.ca/jobs?q='
    headers ={
            'User-Agent':'Mozilla/'+str(i)+'.0 (Macintosh; Intel Mac OS X 10.'+str(x)+'; rv:53.0) Gecko/20100101 Firefox/'+str(j)+'.0'
                }
    return headers

def text_cleaner(website):
    '''
    This function just cleans up the raw html so that I can look at it.
    Inputs: a URL to investigate
    Outputs: Cleaned text only
    '''
    try:
        site = requests.get(website, headers = headers()) # Connect to the job posting
    except: 
        return   # Need this in case the website isn't there anymore or some other weird connection problem 

    soup_obj = BeautifulSoup(site.text, "html.parser") # Get the html from the site

    for script in soup_obj(["script", "style"]):
        script.extract() # Remove these two elements from the BS4 object

    text = soup_obj.get_text() # Get the text from this
    lines = (line.strip() for line in text.splitlines()) # break into lines
    chunks = (phrase.strip() for line in lines for phrase in line.split("  ")) # break multi-headlines into a line each

    def chunk_space(chunk):
        chunk_out = chunk + ' ' # Need to fix spacing issue
        return chunk_out  

    text = ''.join(chunk_space(chunk) for chunk in chunks if chunk).encode('utf-8') # Get rid of all blank lines and ends of line

    # Now clean out all of the unicode junk (this line works great!!!)
    try:
        text = text.decode('unicode_escape').encode('ascii', 'ignore') # Need this as some websites aren't formatted
    except:                                                            # in a way that this works, can occasionally throw
        return                                                         # an exception

    text = re.sub(r"[^a-zA-Z.+3]"," ", str(text))  # Now get rid of any terms that aren't words (include 3 for d3.js)
                                                # Also include + for C++

    text = text.lower().split()  # Go to lower case and split them apart
    stop_words = set(stopwords.words("english")) # Filter out any stop words
    text = [w for w in text if not w in stop_words]
    text = list(set(text)) # Last, just get the set of these. Ignore counts (we are just looking at whether a term existed
                            # or not on the website)
    return text

# note the function itself doesn't return anything if you run this cell

# %%
def skills_info_test(city = None, state = None, job_title = None):
    final_job = str(job_title)
    columns = ["job_title","job_link","job_description","company_name","location","summary","salary"]
    df = pd.DataFrame(columns = columns)
    num = (len-(df)+1)
    
    for start in range(0,50,10):
        
    
    # Make sure the city specified works properly if it has more than one word (such as San Francisco)
        if city is not None:
            final_city = city.split() 
            final_city = '+'.join(word for word in final_city)
            final_site_list = ['http://ca.indeed.com/jobs?q=', final_job, '&l=', final_city,
                    '%2C+', state,'&start=',str(start)] # Join all of our strings together so that indeed will search correctly
        else:
            final_site_list = ['http://ca.indeed.com/jobs?q="', final_job, '"','&start=', str(start)]

        final_site = ''.join(final_site_list) # Merge the html address together into one string
        print(final_site)

        base_url = 'http://ca.indeed.com'
    
        try:
            html = requests.get(final_site, headers = headers()) # Open up the front page of our search first
        except:
            print('That city/state combination did not have any jobs. Exiting . . .') # In case the city is invalid
            return
        
        soup = BeautifulSoup(html.text, 'html.parser') # Get the html from the first page
    
        job_link_area = soup.find(id = 'resultsCol')
        
        #target = BeautifulSoup(html.text, "html.parser") # Get the html from the first page
        #targetElements = target.findAll('div',attrs={'class':'row result'})
        
        
        
        #for elem in targetElements:
            #job_link = "%s%s" % (base_url,elem.find('a').get('href'))
            #job_post.append(job_link)
            
        for div in soup.find_all(name = "div", attrs = {"class":"row"}):
            #specifying row num for index of job posting in dataframe
            job_post = []
            num = (len(df)+1)
            
            #creating an empty list to hold the data for each posting
            
            
        
            # grabbing job title
        
            for a in div.find_all(name = "a", attrs = {"data-tn-element":"jobTitle"}):
                job_post.append(a["title"])
        
            # grabbing job link
            job_descriptions = [] 
            for a in div.find_all(name = "a", attrs = {"data-tn-element":"jobTitle"}):
                job_post.append(str(base_url) + str(a["href"]))
                
                final_description = text_cleaner(str(base_url) + str(a['href']))
                job_post.append(final_description)
                #sleep(0)
             # grabbing detailed description
            
            
            
            #grabbing company name
        
            company = div.find_all(name = "span", attrs = {"class":"company"})
        
            if len(company) > 0:
                for b in company:
                    job_post.append(b.text.strip())
            else:
                sec_try = div.find_all(name = "span", attrs = {"class":"result-link-source"})
            
                for span in sec_try:
                    job_post.append(span.text)
                
            # grabbing location name
        
            c = div.findAll('span',attrs = {'class':'location'})
        
            for span in c:
            
                job_post.append(span.text)
        
            #grabing summary text
        
            d = div.findAll('span', attrs = {'class':'summary'})
            for span in d:
                job_post.append(span.text.strip())
                
           
   
            # grabbing salary
    
            try:
                job_post.append(div.find('nobr').text)
        
            except:
                try:
                    div_2 = div.find(name = 'div', attrs = {"class":"sjcl"})
                    div_3 = div_2.find("div")
                    job_post.append(div_3.text.strip())
                except:
                    job_post.append("Nothing_Found")
                
            #appending list of job post to a data frame at index num
        
            df.loc[num] = job_post
        
    
    
    return(df)

# %%
pd.set_option('display.max_colwidth', -1)
df1 = skills_info_test(city = 'Toronto', state = 'ON', job_title = "Data+Scientist")
# Out:
# http://ca.indeed.com/jobs?q=Data+Scientist&l=Toronto%2C+ON&start=0
# http://ca.indeed.com/jobs?q=Data+Scientist&l=Toronto%2C+ON&start=10
# http://ca.indeed.com/jobs?q=Data+Scientist&l=Toronto%2C+ON&start=20
# http://ca.indeed.com/jobs?q=Data+Scientist&l=Toronto%2C+ON&start=30
# http://ca.indeed.com/jobs?q=Data+Scientist&l=Toronto%2C+ON&start=40

# %%
df1
# Out:
#                                      job_title  \
# 1   Data Scientist
# 2   Data Developer (14 month contract)
# 3   Data Scientist, AML Risk Analytics
# 4   Data Scientist
# 5   Data Scientist
# 6   Data Scientist
# 7   Data Scientist
# 8   Associate Data Scientist
# 9   Data Scientist: Advanced Analytics
# 10  Data Scientist: Integrity
# 11  Data Scientist - Market Research
# 12  Junior Data Scientist
# 13  Data Scientist
# 14  Data Scientist - Machine Learning
# 15  Data Scientist
# 16  Data Scientist
# 17  Data Developer (14 month contract)
# 18  Energy Data Scientist
# 19  Research Scientist, Google Brain (Canada)
# 20  Research Scientist - Machine Learning
# 21  Data Scientist
# 22  Applied Research Scientist
# 23  Applied Data Scientist
# 24  SENIOR DATA SCIENTIST
# 25  Data Scientist
# 26  Data Analyst
# 27  Data Science (Team Lead)
# 28  Data Scientist, AML Risk Analytics
# 29  Data Scientist - Machine Learning
# 30  Data Scientist
# ..             ...
# 46  Data Developer (14 month contract)
# 47  Data Scientist, AML Risk Analytics
# 48  Junior Imaging Analyst
# 49  Data Scientist
# 50  Analytics - Data Science Consultant
# 51  Data Scientist
http://ca.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0BlF99n-nNBr1TbUFPQlXHtlU_xPAKaoVNBEsTN_g4pwpKD7IeBJF73MCeEjZIH8pC4lXS27h3Q2agxWKWr_CVhFqxqIh1aMRGkEHlGtWwhVUaXcm8O2iB23awlXoD7jN9kl_hLy4qrthi6VOXHpB1v2Geze2BIe4cmJ2usMLRoAJcHcGsRcwA_9GD3GaQNvM_wROvlRoahYx0Mg2S4TWEywBJUxaP22HmKTGHnftmlp2RsYI0ikJ2810W0vBzVFsHCKHG-vreuNKIs7RmbC2dhi5eWVJhmRRYSn54futRGe-he_lCvmHFpQr4uTJxpN9I_ocq0orlQuszxkU-mRMJcjdMlV75EZWbWNOvpw-LLeyXunWMxCPcZ0C77GiUHP27laOBO3_YzyVU9ZOOUgoqLe6miWea4b7z7y5a0IgAfuxIsZWI-xA3Q&p=4&sk=&fvj=1
# 75  http://ca.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0Dl0EE_WhFXbpizkrl8nywi6L-ueye5Z0RVrGddRMF4VcenHcfJ6Sm70jbXDr9BXYjDukEP1GuEvFrqCRDv7b48Viu2RdIktP-UDr_L8UZAdyKnZlhUVhxNyLgD6xJIhpJR30Zl_8hYjb-m0B-n_2NgRteHwqb0Ce1wp5kSonLQOqq8sN_phAz50JygVJXsM8vlKf2kmZpZY8KjCU4DDHsDc91dQBfcdZQ3CYoZbUqiVS4-PhKjlD5LrNoGHG6e5l5T7-GEx2ve5yayZxxtbhpoN9K6dBuGTMlz7N0W-z7ewvq2U5jGszsr0o_2zRsoRqVjAhPYHqCojubb8EzVtjc2AAaRAkiALa3bSDkIM6R6w27wZp0jiagxapER71VicbtAikwNRRdR0gMmL8gQhPK6hADwxgNJUDa_ohKVOdqQzmv1R07ntO8OJdMc3gzzo6WekYmH1XDZNXo6otGXTpcgl2mCKTIj6UPT5qWA1xYZNnarILUIgfTUHX7doCDg_jrVGGRZWydXYhRBf8SNcpEAfDwx4PwK7whtbLtVWaJsWg==&p=5&sk=&fvj=0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            job_description  \
# 1   [top, twitter, jobs, data, tube, window, royal, security, linkedin, accessibility, facebook, canada, backtotop, rbc, toronto, link, new, legal, submit, menu, careers, view, opens, general, instagram, rbc.com, b, icon, ontario, website, scientist, bank, technology, application, privacy, mobile]
# 2   [inthis, inactivity.job, primary, set, sign, beginning, jobs, content, ok, work, signed, section.return, teamsgo, previous, loyaltyonelearn, jobpagebasic, position, organization, friend, candidate, main, accessibility, searchmy, disconnect, home, pageprintable, job, locations, refer, page, loyaltyone, reset, matching, advanced, candidatesubmit, profile, inactivity., search, saved, automatically, options, minutes, posting, terms, co., jobrefer, minutes.you, b, use, timer, loyaltyoneour, friendrefer, formatreturn, submissions, section., minutes.click, cart, schedule, searches, out.this, searchcareers, opportunitieslife, account, session, end, type, privacy, location, service]
# ...
# 1   RBC                                Toronto, ON
# 2   LoyaltyOne                         Toronto, ON
# 3   RBC                                Toronto, ON
# 4   Deloitte                           Greater Toronto Area, ON
# 5   First Derivatives                  Toronto, ON
# 6   Scotiabank                         Toronto, ON
# 7   BMO Financial Group                Toronto, ON
# 8   The Nielsen Company                Markham, ON
# 9   IBM                                Toronto, ON
# 10  HomeStars                          Toronto, ON
# 11  FOUND PEOPLE INC.                  Toronto, ON
# 12  Adlib Software                     Burlington, ON
# 13  Veritaaq                           Greater Toronto Area, ON
# 14  RBC                                Toronto, ON
# 15  Quantfury Ltd                      Toronto, ON
# 16  Quantfury Ltd                      Toronto, ON
# 17  LoyaltyOne                         Toronto, ON
# 18  Energy Profiles Limited            Toronto, ON
# 19  Google                             Toronto, ON
# 20  Element AI                         Toronto, ON
# 21  Wish                               Toronto, ON
# 22  Element AI                         Toronto, ON
# 23  Peak Power Inc                     Toronto, ON
# 24  Intelerad                          Toronto, ON
# 25  EquitySim                          Toronto, ON
# 26  Decision Resources Group           Toronto, ON
# 27  Unata Inc.                         Toronto, ON
# 28  RBC                                Toronto, ON
# 29  RBC                                Toronto, ON
# 30  RBC                                Toronto, ON
# ..  ...                                        ...
# 46  LoyaltyOne                         Toronto, ON
# 47  RBC                                Toronto, ON
# 48  Sunnybrook Health Sciences Centre  Toronto, ON
# 49  Quantfury Ltd                      Toronto, ON
# 50  Accenture                          Toronto, ON
# 51  Jobspring Partners                 Toronto, ON
# 52  TELUS Communications               Toronto, ON
# 53  Rakuten Kobo Inc.                  Toronto, ON
# 54  Google                             Toronto, ON
# 55  Canadian Tire: Corporate           Toronto, ON
# 56  Hosted Property Management         Toronto, ON
# 57  Ruby                               Toronto, ON
# 58  RBC                                Toronto, ON
# 59  Quantfury Ltd                      Toronto, ON
# 60  RBC                                Toronto, ON
# 61  LoyaltyOne                         Toronto, ON
# 62  RBC                                Toronto, ON
# 63  Ruby                               Toronto, ON
# 64  Capital One                        Toronto, ON
# 65  Aimia                              Toronto, ON
# 66  AMZN CAN Fulfillment Svcs, Inc     Toronto, ON
# 67  PointClickCare                     Mississauga, ON
# 68  Maxxam Analytics                   Mississauga, ON
# 69  MedReleaf Corp.                    Markham, ON
# 70  Decision Resources Group           Toronto, ON
# 71  EQ Works                           Toronto, ON
# 72  Element AI                         Toronto, ON
# 73  RBC                                Toronto, ON
# 74  Quantfury Ltd                      Toronto, ON
# 75  RBC                                Toronto, ON
#
#                                                                                                                                                                 summary  \
# 1   Big Data Technologies:. The Data Scientist will design, implement and deliver algorithmic, model-driven, statistical or machine learning solutions in...
# 2   Alliance Data participates in E-Verify. Work with large volumes of data; He/she will work closely with Data Scientists and Business Consultants to understand...
# 3   Big Data Technologies:. Data Science Innovation Lead. Working throughout the pipeline from defining a research question, collecting data, analyzing data,...
# 4   Additionally, the Data Scientist:. The Global Technology Services-Business Services Group is seeking a Data Scientist....
# 5   Data Scientists explore vast amounts of information to detect patterns, trends and correlations that enable businesses to improve their products, services and...
# 6   Experience cleaning, transforming and visualizing large data sets working with various data formats (e.g....
# 7   Supporting the data infrastructure and data repository build for analytical needs. We are looking for a Data Scientist that will help us discover the...
# 8   Assure the integrity of project data, including data extraction, storage, manipulation, processing and analysis. Exceptional aptitude for data analysis....
# 9   The Data Scientist will be familiar with key internal and external data sources and how they are gathered and retrieved;...
# 10  HomeStars is seeking a data scientist to capture insights and measure all released developments. A keen eye for implied meanings in data....
# 11  Our Client, a leading Market Research company in Toronto is looking for a data scientist with market research experience who will provide analytic leadership to...
# 12  Data Scientist has:. Data Scientist will work with:. Data visualization tools. You are obsessed with solving big data problems and determining value of dark...
# 13  We are looking for an exceptional data scientist to synthesize and leverage our unique market position as a Canadian leader in data services....
# 14  Joining the Digital Data & Analytics team as a Senior Digital Data Scientist, you will have the opportunity to analyze, design and implement data solutions...
# 15  Data scientist (Machine Learning Expert). Experience working with data bases, including knowledge of SQL....
# 16  Data scientist (Machine Learning Expert). Experience working with data bases, including knowledge of SQL....
# 17  Alliance Data participates in E-Verify. Work with large volumes of data; He/she will work closely with Data Scientists and Business Consultants to understand...
# 18  Energy Data Scientists are an integral part of our Data Systems Group. To that end, Energy Data Scientists typically complete several rotations in their first...
# 19  From creating experiments and prototyping implementations to designing new learning algorithms, Research Scientists work on challenges in machine perception,...
# 20  Explaining the data audit and data quality control to partners and clients; Building strong collaborative relationship with scientists, software developers, and...
# 21  We’re looking for a talented Data Scientist to continue to drive decisions company-wide through the use of statistical modeling and machine learning....
# 22  Explaining the data audit and data quality control to partners and clients; Building strong collaborative relationship with scientists, software developers, and...
# 23  Experience with Data processing & cleaning (understanding the data pipeline). We are seeking a self-motivated *Applied Data Scientist*....
# 24  Data science analysis, algorithms development and reporting. Guide and contribute to the data analysis and machine intelligence efforts of CDS (Clinical...
# 25  An experienced data analyst or scientist with a master's degree in an analytical field, such as Computer Science, Engineering, Mathematics, and Statistics)....
# 26  In this role, you will work with a team of 6 data scientists to mine and make sense of 3 to 8 large, distinct datasets for the US healthcare market:....
# 27  LEAD DATA SCIENTIST. You might be the right fit for us if you’re an accomplished, seasoned, battle-scarred data scientist with a history of enterprise software...
# 28  Big Data Technologies:. Data Science Innovation Lead. Working throughout the pipeline from defining a research question, collecting data, analyzing data,...
# 29  Joining the Digital Data & Analytics team as a Senior Digital Data Scientist, you will have the opportunity to analyze, design and implement data solutions...
# 30  Big Data Technologies:. The Data Scientist will design, implement and deliver algorithmic, model-driven, statistical or machine learning solutions in...
# ..                                                                                                                                                       ...
# 46  Alliance Data participates in E-Verify. Work with large volumes of data; He/she will work closely with Data Scientists and Business Consultants to understand...
# 47  Big Data Technologies:. Data Science Innovation Lead. Working throughout the pipeline from defining a research question, collecting data, analyzing data,...
# 48  The Junior Imaging Analyst will conduct brain image analysis of structural and functional imaging data in normal and patient populations including dementia and...
# 49  Data scientist (Machine Learning Expert). Experience working with data bases, including knowledge of SQL....
# 50  Evidence data, digital marketing data. The Data Analytics. Specific Industry’s data sets. Unstructured data sources for analysis....
# 51  A rapidly growing start up located on King West in Toronto is looking for a Data Scientist to join their team. The right candidate will be doing forecasting....
# 52  Ability to develop experimental and analytic plans for data modeling processes with the assistance of data scientist(s)....
# 53  Senior Data and Machine Learning Scientist. We are seeking a Data and Machine Learning Scientist to join our Big Data team....
# 54  From creating experiments and prototyping implementations to designing new architectures, Research Scientists and Software Engineers work on challenges in...
# 55  Senior Data Scientist - C04LAQ. Integrating multiple systems and data sets. Demonstrated superior analytical, and data mining skills....
# 56  Data Mining, Data Analysis, Optimization, Hospitality, Team Player, Pricing, Financial Analysis, Hotel Revenue Management....
# 57  Strong analytical and quantitative skills—you will work with data scientists. As a Data Developer, some of your duties will include designing A/B test...
# 58  Joining the Digital Data & Analytics team as a Senior Digital Data Scientist, you will have the opportunity to analyze, design and implement data solutions...
# 59  Data scientist (Machine Learning Expert). Experience working with data bases, including knowledge of SQL....
# 60  Big Data Technologies:. The Data Scientist will design, implement and deliver algorithmic, model-driven, statistical or machine learning solutions in...
# 61  Alliance Data participates in E-Verify. Work with large volumes of data; He/she will work closely with Data Scientists and Business Consultants to understand...
# 62  Big Data Technologies:. Data Science Innovation Lead. Working throughout the pipeline from defining a research question, collecting data, analyzing data,...
# 63  Strong analytical and quantitative skills—you will work with data scientists. As a Data Developer, some of your duties will include designing A/B test...
# 64  Data Scientist – KDD Attendees. Writing software to clean and investigate large, messy data sets of numerical and textual data....
# 65  Participate and work with Data Management, Data Security, and Data Architect to identify and ingest, clean, aggregate, and integrate data from various...
# 66  Manage and develop a small team of Data Scientists. Data Scientist with strong analytical, communication and project management skills to join our team....
# 67  Reporting to the Vice President, Data Intelligence, the Associate Data Scientist will be responsible for understanding, interpreting, manipulating, grouping and...
# 68  Prepare data packages for client’s reports. As a LABORATORY DATA ANALYST , your main responsibilities are to :....
# 69  Junior Staff Scientist*. Basic data logging and analysis. Based out of Markham, Ontario....
# 70  In this role, you will work with a team of data scientists to mine and make sense of large, distinct datasets that focus on different aspects of the US...
# 71  Machine learning, big data engineering and rich (location) data sets. Your role will involve working very closely with our CTO, data scientists and the extended...
# 72  Work closely with clients to gather information about their strategy, value drivers, and data assets; You will work with and learn from a range of experts, from...
# 73  Joining the Digital Data & Analytics team as a Senior Digital Data Scientist, you will have the opportunity to analyze, design and implement data solutions...
# 74  Data scientist (Machine Learning Expert). Experience working with data bases, including knowledge of SQL....
# 75  Big Data Technologies:. The Data Scientist will design, implement and deliver algorithmic, model-driven, statistical or machine learning solutions in...
#
#            salary
# 1   Nothing_Found
# 2   Nothing_Found
# 3   Nothing_Found
# 4   Nothing_Found
# 5   Nothing_Found
# 6   Nothing_Found
# 7   Nothing_Found
# 8   Nothing_Found
# 9   Nothing_Found
# 10  Nothing_Found
# 11  Nothing_Found
# 12  Nothing_Found
# 13  Nothing_Found
# 14  Nothing_Found
# 15  Nothing_Found
# 16  Nothing_Found
# 17  Nothing_Found
# 18  Nothing_Found
# 19  Nothing_Found
# 20  Nothing_Found
# 21  Nothing_Found
# 22  Nothing_Found
# 23  Nothing_Found
# 24  Nothing_Found
# 25  Nothing_Found
# 26  Nothing_Found
# 27  Nothing_Found
# 28  Nothing_Found
# 29  Nothing_Found
# 30  Nothing_Found
# ..            ...
# 46  Nothing_Found
# 47  Nothing_Found
# 48  Nothing_Found
# 49  Nothing_Found
# 50  Nothing_Found
# 51  Nothing_Found
# 52  Nothing_Found
# 53  Nothing_Found
# 54  Nothing_Found
# 55  Nothing_Found
# 56  Nothing_Found
# 57  Nothing_Found
# 58  Nothing_Found
# 59  Nothing_Found
# 60  Nothing_Found
# 61  Nothing_Found
# 62  Nothing_Found
# 63  Nothing_Found
# 64  Nothing_Found
# 65  Nothing_Found
# 66  Nothing_Found
# 67  Nothing_Found
# 68  Nothing_Found
# 69  Nothing_Found
# 70  Nothing_Found
# 71  Nothing_Found
# 72  Nothing_Found
# 73  Nothing_Found
# 74  Nothing_Found
# 75  Nothing_Found
#
# [75 rows x 7 columns]

# %%
def test(city = None, state = None, job_title = None):
    final_job = str(job_title)
    df = pd.DataFrame() 
    
    for page in range(1,6):
        page = (page-1) * 10  
    
    # Make sure the city specified works properly if it has more than one word (such as San Francisco)
        if city is not None:
            final_city = city.split() 
            final_city = '+'.join(word for word in final_city)
            final_site_list = ['http://ca.indeed.com/jobs?q=', final_job, '&l=', final_city,
                    '%2C+', state,'&start=',str(page)] # Join all of our strings together so that indeed will search correctly
        else:
            final_site_list = ['http://ca.indeed.com/jobs?q="', final_job, '"','&start=', str(page)]

        final_site = ''.join(final_site_list) # Merge the html address together into one string
        print(final_site)

        base_url = 'http://ca.indeed.com'
    
        try:
            html = requests.get(final_site, headers = headers()) # Open up the front page of our search first
        except:
            print('That city/state combination did not have any jobs. Exiting . . .') # In case the city is invalid
            return
        
        soup = BeautifulSoup(html.text, 'html.parser') # Get the html from the first page
        targetElements = soup.findAll('div', attrs={'class' : 'row result'})
        
        
        for elem in targetElements:
            job_link = "%s%s" % (base_url,elem.find('a').get('href'))
            df = df.append({"job_link":job_link}, ignore_index=True)
        
    return df

# %%
l = test(city = 'Toronto', state = 'ON', job_title = "Data+Scientist")
# Out:
# http://ca.indeed.com/jobs?q=Data+Scientist&l=Toronto%2C+ON&start=0
# http://ca.indeed.com/jobs?q=Data+Scientist&l=Toronto%2C+ON&start=10
# http://ca.indeed.com/jobs?q=Data+Scientist&l=Toronto%2C+ON&start=20
# http://ca.indeed.com/jobs?q=Data+Scientist&l=Toronto%2C+ON&start=30
# http://ca.indeed.com/jobs?q=Data+Scientist&l=Toronto%2C+ON&start=40

# %%
l
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               job_link
# 0   http://ca.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0Dl0EE_WhFXbpizkrl8nywi6L-ueye5Z0RVrGddRMF4VcenHcfJ6Sm70jbXDr9BXYhJW1NEeVDe0qo0ac2-_gj9SlseVbeUS-HSYJBulSeV4oh49Ft4nqtv9bhswSmmIXQ2I2QRjvGF_eaVJJWNhgMZwcI-fJYdcvvNwVrpqB-5WFpQ5fPVm_VI2GnWRQ1a4AqEgvsXCQEOEsVoYNxOY2x6ChusgnKFmlJREb0ZCPMTiqW1LmObpjINAbOG2W5nVKeASDAOjq3O69nLrLNfBuiAWUACMcr5AIhJ_RT4p-YnC6SGmcXeBoCX25GBP9PZZJ8Y-ljTgzgNYA8qlRpKD9hqofNN5tCMK0vV6VIYDyPG_G3WEaO1ctKd3ddd5LjHfyvCfjZgzswxN5hq5cdTB1vDl7AwTt1dFu9tabHkVhBMroUyoGwNfA-Dic1FGANm1Aa_drX3YO6YSqEfaKUZ73WlU5GRqSdWyi6NTD3lfRO5vQx1fZQSPYnXGdCfXaaDMLvTZ1B5lOxbB_fBsi4j94KzGEo27p9dNtpe0Ambc5QBLg==&p=1&sk=&fvj=0
# 1   http://ca.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0Dl0EE_WhFXbpizkrl8nywi6L-ueye5Z0RVrGddRMF4VcenHcfJ6Sm70jbXDr9BXYhJscKp_ZnISfkbEkZGiHl21sOa7pR3ffcOPduTls4AZzycp0PLfP26XYs4Gp7vrc9hliZ9NZHCYNtWnmOFj2w65xtRVvTvZmnqwDJYiU8euc_RduCPahfyb9eBU_I6Z8Obqax2gJ9yrgsTpp_fXisLfwWJ5pqLazgprNCFNfqH0vdEeBjqTSMO2iQfYwndwa9IBWIN5HEWTelq0ATMh2vEUV5KsIM2WzNn7dUi2uJZFr-w7bE3pEBj4Fd7kfcXkI3cwqii2QA0zkTAql3M5LNaVBN4ggGxaX4rEmudrBz-RcRMeyyla_QrlkJsNGhotDxY29Ne10YggHDyZhLMa-BOt2PZhLNSfHAfC6VmbDbDflhWzlBt162uEgnfMZ1kjJDlkQO4x6AbMFi4HAnTPQn4UNX7G6fCV0Ut4fkSoBFMuieipCT4Zvi7BT9flVkh1pOfQ_zeIK3GYkK8sA5yEC5hwze1H-RIXHEYDUmcnngwvsZbdDLWhzPqU3R1AZcM9l4=&p=2&sk=&fvj=0
# 2   http://ca.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0
# %%
for i in df1["summary"]:
    
    # clean and tokenize document string
    raw = i.lower()
    tokens = tokenizer.tokenize(raw)
    
    data_words = ["data","science","scientist","engineering","analytics","analysis"]
    
    rev_data = [i for i in tokens if not i in data_words]
    
    # remove stop words from tokens
    stopped_tokens = [i for i in rev_data if not i in en_stop]
    
    # stem tokens
    stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
    
    # add tokens to list
    texts.append(stemmed_tokens)

# %%
dictionary = corpora.Dictionary(texts)

# %%
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=2, id2word = dictionary, passes=20)

# %%
print(ldamodel.print_topics(num_topics=3, num_words=20))
# Out:
#   File "<ipython-input-15-d7a42d01d1d3>", line 1
#     print(ldamo del.print_topics(num_topics=3, num_words=20))
#                   ^
# SyntaxError: invalid syntax

# %%
df1('city = None, state = None, job_title = None'):
# Out:
#                                             job_title  \
# 1                                      Data Scientist
# 2                                      Data Scientist
# 3                                       Data Engineer
# 4                          Applied Research Scientist
# 5                  Data Scientist: Advanced Analytics
# 6                                        Data Analyst
# 7                                      Data Scientist
# 8                                      Data Scientist
# 9           Research Scientist, Google Brain (Canada)
# 10                                       Data Analyst
# 11                                     Data Scientist
# 12                                     Data Scientist
# 13                                     Data Scientist
# 14                 Data Developer (14 month contract)
# 15                  Data Scientist - Machine Learning
# 16                  Data Scientist - Machine Learning
# 17                                     Data Scientist
# 18  Research Scientist Lead – Computer Vision/Deep...
# 19                              Energy Data Scientist
# 20                                     Data Scientist
# 21                     Student Research Collaboration
# 22                     Data Scientist – KDD Attendees
# 23                                     Data Scientist
# 24                                     Data Scientist
# 25                                     Data Scientist
# 26                                     Data Scientist
# 27                        Data Analyst/ Brandtracking
# 28                                      Data Engineer
# 29                 Data Developer (14 month contract)
# 30                                     Data Scientist
# ..                                                ...
# 46                                     Data Scientist
# 47                                      Data Engineer
# 48                              Senior Data Scientist
# 49                                 Research Associate
# 50           SENIOR AQUATIC RISK ASSESSMENT SCIENTIST
# 51                Analytics - Data Science Consultant
# 52                         Associate Data Scientist 1
# 53                             Applied Data Scientist
# 54                                 Sr. Data Scientist
# 55  Neural Network/Machine Learning Engineer or Da...
# 56                         Machine Learning Scientist
# 57                            Manager, Data Analytics
# 58                 Data Developer (14 month contract)
# 59                  Data Scientist - Machine Learning
# 60                                     Data Scientist
# 61                                     Data Scientist
# 62                                      Data Engineer
# 63                            Manager, Data Analytics
# 64                                     Data Scientist
# 65                    Data Scientist, Journey Science
# 66                              Senior Data Scientist
# 67              Senior Research Associate, Evaluation
# 68                              Analytical Consultant
# 69                           Data Scientist/ Engineer
# 70                   Bioinformatician, Data Scientist
# 71              Big Data Engineer, Advanced Analytics
# 72                                 Research Associate
# 73                 Data Developer (14 month contract)
# 74                  Data Scientist - Machine Learning
# 75                                     Data Scientist
#
#                                       company_name                  location  \
# 1                                              RBC               Toronto, ON
# 2                                    Quantfury Ltd               Toronto, ON
# 3                                  Morneau Shepell               Toronto, ON
# 4                                       Element AI               Toronto, ON
# 5                                              IBM               Toronto, ON
# 6                               Manulife Financial               Toronto, ON
# 7                                       Scotiabank               Toronto, ON
# 8                                         Veritaaq  Greater Toronto Area, ON
# 9                                           Google               Toronto, ON
# 10                        Decision Resources Group               Toronto, ON
# 11                                       EquitySim               Toronto, ON
# 12                                   Quantfury Ltd               Toronto, ON
# 13                            TELUS Communications               Toronto, ON
# 14                                      LoyaltyOne               Toronto, ON
# 15                                             RBC               Toronto, ON
# 16                                             RBC               Toronto, ON
# 17                                   Quantfury Ltd               Toronto, ON
# 18                                          Ecopia               Toronto, ON
# 19                         Energy Profiles Limited               Toronto, ON
# 20                                            Wish               Toronto, ON
# 21                                          Google               Toronto, ON
# 22                                     Capital One               Toronto, ON
# 23                                            PUSH               Toronto, ON
# 24                Opta Information Intelligence LP               Markham, ON
# 25                                    Klick Health               Toronto, ON
# 26                              Jobspring Partners               Toronto, ON
# 27                        Decision Resources Group               Toronto, ON
# 28                                 Morneau Shepell               Toronto, ON
# 29                                      LoyaltyOne               Toronto, ON
# 30                                             RBC               Toronto, ON
# ..                                             ...                       ...
# 46                                   Quantfury Ltd               Toronto, ON
# 47                                 Morneau Shepell               Toronto, ON
# 48                        Canadian Tire: Corporate               Toronto, ON
# 49               Sunnybrook Health Sciences Centre               Toronto, ON
# 50  Ministry of the Environment and Climate Change               Toronto, ON
# 51                                       Accenture               Toronto, ON
# 52                                  PointClickCare           Mississauga, ON
# 53                                  Peak Power Inc               Toronto, ON
# 54                  AMZN CAN Fulfillment Svcs, Inc               Toronto, ON
# 55                            Brainwerx Group Inc.  Greater Toronto Area, ON
# 56                                    integrate.ai               Toronto, ON
# 57                                             RBC               Toronto, ON
# 58                                      LoyaltyOne               Toronto, ON
# 59                                             RBC               Toronto, ON
# 60                                             RBC               Toronto, ON
# 61                                   Quantfury Ltd               Toronto, ON
# 62                                 Morneau Shepell               Toronto, ON
# 63                                             RBC               Toronto, ON
# 64                           Rogers Communications              Brampton, ON
# 65                             BMO Financial Group               Toronto, ON
# 66                                      Scotiabank               Toronto, ON
# 67                             Cancer Care Ontario               Toronto, ON
# 68                                         Equifax               Toronto, ON
# 69                         Pandion Search Partners               Toronto, ON
# 70           Ontario Institute for Cancer Research               Toronto, ON
# 71                                           Aimia               Toronto, ON
# 72           Ontario Institute for Cancer Research               Toronto, ON
# 73                                      LoyaltyOne               Toronto, ON
# 74                                             RBC               Toronto, ON
# 75                                             RBC               Toronto, ON
#
#                                               summary         salary
# 1   Data Science Innovation. Data Science Project ...  Nothing_Found
# 2   Data scientist (Machine Learning Expert). Expe...  Nothing_Found
# 3   Implementation of Big Data infrastructure and ...  Nothing_Found
# 4   Explaining the data audit and data quality con...  Nothing_Found
# 5   The Data Scientist will be familiar with key i...  Nothing_Found
# 6   Work with Data Scientists to transform busines...  Nothing_Found
# 7   Experience cleaning, transforming and visualiz...  Nothing_Found
# 8   We are looking for an exceptional data scienti...  Nothing_Found
# 9   From creating experiments and prototyping impl...  Nothing_Found
# 10  In this role, you will work with a team of 6 d...  Nothing_Found
# 11  An experienced data analyst or scientist with ...  Nothing_Found
# 12  Data scientist (Machine Learning Expert). Expe...  Nothing_Found
# 13  5 or more years of data analytics experience c...  Nothing_Found
# 14  Alliance Data participates in E-Verify. Work w...  Nothing_Found
# 15  Joining the Digital Data & Analytics team as a...  Nothing_Found
# 16  Joining the Digital Data & Analytics team as a...  Nothing_Found
# 17  Data scientist (Machine Learning Expert). Expe...  Nothing_Found
# 18  Research Scientist Lead – Computer Vision/Deep...  Nothing_Found
# 19  Energy Data Scientists are an integral part of...  Nothing_Found
# 20  We’re looking for a talented Data Scientist to...  Nothing_Found
# 21  From creating experiments and prototyping impl...  Nothing_Found
# 22  Data Scientist – KDD Attendees. Writing softwa...  Nothing_Found
# 23  You will be working closely with everything fr...  Nothing_Found
# 24  As R&D team of SCM Insurance group, we deliver...  Nothing_Found
# 25  Reports to the SVP Data Science. Our tool set ...  Nothing_Found
# 26  A rapidly growing start up located on King Wes...  Nothing_Found
# 27  In this role, you will work with a team of dat...  Nothing_Found
# 28  Implementation of Big Data infrastructure and ...  Nothing_Found
# 29  Alliance Data participates in E-Verify. Work w...  Nothing_Found
# 30  Data Science Innovation. Data Science Project ...  Nothing_Found
# ..                                                ...            ...
# 46  Data scientist (Machine Learning Expert). Expe...  Nothing_Found
# 47  Implementation of Big Data infrastructure and ...  Nothing_Found
# 48  Senior Data Scientist - C04LAQ. Integrating mu...  Nothing_Found
# 49  A new clinician scientist and faculty at the S...  Nothing_Found
# 50  Scientific and mathematical analyses/ approach...  Nothing_Found
# 51  Evidence data, digital marketing data. The Dat...  Nothing_Found
# 52  Reporting to the Vice President, Data Intellig...  Nothing_Found
# 53  Experience with Data processing & cleaning (un...  Nothing_Found
# 54  Manage and develop a small team of Data Scient...  Nothing_Found
# 55  Data Acquisition, Cleaning, and Transformation...  Nothing_Found
# 56  Machine Learning Scientist. Work with architec...  Nothing_Found
# 57  Understand structured data :. 3+ years of expe...  Nothing_Found
# 58  Alliance Data participates in E-Verify. Work w...  Nothing_Found
# 59  Joining the Digital Data & Analytics team as a...  Nothing_Found
# 60  Data Science Innovation. Data Science Project ...  Nothing_Found
# 61  Data scientist (Machine Learning Expert). Expe...  Nothing_Found
# 62  Implementation of Big Data infrastructure and ...  Nothing_Found
# 63  Understand structured data :. 3+ years of expe...  Nothing_Found
# 64  The Data Scientist position reports to the Dir...  Nothing_Found
# 65  Journey Scientists will. Extensive work experi...  Nothing_Found
# 66  Coach a team of data scientists for analytics....  Nothing_Found
# 67  Familiarity with cancer screening program data...  Nothing_Found
# 68  Knowledge of Data Management and Data Architec...  Nothing_Found
# 69  Development of new data and the refinement of ...  Nothing_Found
# 70  Demonstrated experience visualizing complex da...  Nothing_Found
# 71  Participate and work with Data Management, Dat...  Nothing_Found
# 72  The position offers excellent scientific train...  Nothing_Found
# 73  Alliance Data participates in E-Verify. Work w...  Nothing_Found
# 74  Joining the Digital Data & Analytics team as a...  Nothing_Found
# 75  Data Science Innovation. Data Science Project ...  Nothing_Found
#
# [75 rows x 5 columns]

# %%
from
